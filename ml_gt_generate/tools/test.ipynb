# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# data = np.load('./sample_0002.npz')
data = np.load('./sample_0000.npz')

print(data.files)
# Out:
# ['disp', 'depth_aligned', 'left', 'valid_mask', 'sky_mask', 'has_disp', 'stamp']

# %%
print(data['left'].shape)
# Out:
# (320, 320, 3)

# %%
# train_1_0-5 supplement
# fig, ax = plt.subplots(1, 3)
# ax[0].imshow(data['left'])
# ax[1].imshow(data['depth_d455'])
# ax[2].imshow(data['depth_d435'])

# train_1_0-5 dataset
fig, ax = plt.subplots(1, 5)
ax[0].imshow(data['disp'])
ax[1].imshow(data['depth_aligned'])
ax[2].imshow(data['left'])
ax[3].imshow(data['valid_mask'])
ax[4].imshow(data['sky_mask'])


plt.tight_layout() 
plt.show()
